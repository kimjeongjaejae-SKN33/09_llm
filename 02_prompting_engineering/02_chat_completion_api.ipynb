# %% [markdown]
# # Chat Completion API로 프롬프트 엔지니어링 실습
#
# Chat Completion API는 system, user, assistant 역할을 가진 메시지 목록을 모델에 전달하고 생성 응답을 받는 인터페이스이다. system 메시지는 모델의 역할과 공통 규칙을, user 메시지는 현재 요청과 입력 데이터를, assistant 메시지는 대화 이력을 표현한다. API 호출은 프롬프트를 코드로 재사용하고 결과 형식을 자동 처리할 수 있게 해 준다.
#
# 프롬프트 엔지니어링은 단순히 질문을 길게 쓰는 작업이 아니다. 역할, 입력 경계, 처리 규칙, 출력 스키마를 분리해 모델이 따라야 할 계약을 명확히 하는 작업이다. 강점은 빠른 실험과 다양한 업무 적용이며, 한계는 모델 출력이 확률적이고 외부 API 비용·속도·보안 제약이 있다는 점이다. API 키는 코드나 노트북에 저장하지 않고 실행 환경의 비밀 저장소에서 읽어야 한다.
#
# 이번 실습은 API 클라이언트를 준비한 뒤 기사 제목 교정, 상담형 응답, 레시피 제안, JSON 면접 질문 생성에 같은 메시지 구조가 어떻게 재사용되는지 확인한다. 외부 API를 호출하는 셀은 키·네트워크·모델 권한이 준비된 환경에서만 실행하고, 응답 내용은 업무 규칙과 JSON 파싱 결과로 다시 검증한다.

# %% [markdown]
# ### OpenAI Python SDK 설치
#
# 이 셀은 Chat Completion API를 호출하기 위한 `openai` 패키지를 설치한다. 설치가 끝나면 이후 셀의 `OpenAI` 클래스를 가져올 수 있다. 패키지 버전과 인터넷 연결이 필요한 환경 준비 단계이므로, 이미 설치된 수업 환경에서는 실행 결과가 달라질 수 있다.

# %%
# %pip install -U openai python-dotenv
# Out:
# Requirement already satisfied: openai in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (2.52.0)
# Requirement already satisfied: python-dotenv in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from openai) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from openai) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from openai) (2.13.4)
# Requirement already satisfied: sniffio in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from openai) (4.70.0)
# Requirement already satisfied: typing-extensions<5,>=4.14 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from openai) (4.16.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from anyio<5,>=3.5.0->openai) (3.18)
# Requirement already satisfied: certifi in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## PyCharm 환경 설정
#
# 1. PyCharm에서 `08_llm` 폴더를 프로젝트로 연다.
# 2. PyCharm Terminal에서 `python -m pip install openai python-dotenv`를 실행한다.
# 3. `08_llm/.env` 파일에 `OPENAI_API_KEY`를 저장한다.
# 4. 키 값은 코드셀, 출력, Git 또는 공유 파일에 포함하지 않는다.

# %% [markdown]
# ### PyCharm 프로젝트의 `.env` 설정 불러오기
#
# `.env`는 API 키와 실행 설정을 노트북 코드에서 분리하는 로컬 파일이다. `find_dotenv(usecwd=True)`는 현재 Jupyter 작업 폴더부터 상위 폴더로 이동하며 `08_llm/.env`를 찾고, `load_dotenv()`는 그 값을 현재 커널의 환경 변수로 불러온다.
#
# 이 셀은 `OPENAI_API_KEY` 변수가 준비되었는지만 검사하고 실제 값은 출력하지 않는다. 이후 OpenAI SDK와 연동 라이브러리는 환경 변수를 자동으로 사용한다.

# %%
import os

from dotenv import find_dotenv, load_dotenv

dotenv_path = find_dotenv(usecwd=True)
if not dotenv_path:
    raise FileNotFoundError(
        "08_llm 프로젝트 최상위에 .env 파일을 만든 뒤 현재 셀을 다시 실행하세요."
    )

load_dotenv(dotenv_path, override=False)

required_env_vars = [
    "OPENAI_API_KEY",
]

missing_env_vars = [name for name in required_env_vars if not os.getenv(name)]
if missing_env_vars:
    
    missing_names = ", ".join(missing_env_vars)
    raise RuntimeError(f".env 파일의 다음 변수를 확인하세요: {missing_names}")

print("환경 변수 준비 완료")
# Out:
# 환경 변수 준비 완료

# %% [markdown]
# ### API 클라이언트 초기화
#
# `OpenAI` 객체는 이후 모든 API 요청의 진입점이다. 앞 셀에서 읽은 키를 `api_key`에 전달해 `client`에 저장하고, 뒤의 프롬프트 함수들이 이 클라이언트를 재사용한다. 객체 생성은 네트워크 요청 자체가 아니지만, 실제 호출은 유효한 키와 사용 권한을 요구한다.

# %%
from openai import OpenAI

client = OpenAI()

# %% [markdown]
# ### 가장 작은 Chat Completion 요청 만들기
#
# 이 셀은 `messages` 목록 안에 system과 user 메시지를 넣어 모델에 한 번 요청한다. `model`은 사용할 모델 이름, `temperature`는 생성 다양성, `max_completion_tokens`는 생성 길이 상한을 뜻한다. 응답 객체는 다음 셀에서 `choices[0].message.content`로 꺼낸다. 외부 API 호출이므로 실행하면 인증·네트워크·모델 사용 가능 여부를 함께 확인한다.

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",

    # 전달할 대화
    messages=[
        {
            "role":"system", # 모델이 대화 전체에서 따를 역할과 규칙 작성
            "content": [
                {
                    "type": "text",
                    "text": "너는 아주 친절하고, 많은 도움을 주는 챗봇이야"
                }
            ]
        },
        {
            "role": "user", # 사용자가 전달할 실제 입력 값
            "content": [
                {
                    "type": "text",
                    "text": "안녕~ 내 이름은 아이유야~"
                }
            ]
        }
    ],

    # 응답 형식 지정 "text", "json"
    response_format={"type": "text"},
    temperature=1, # 온도 값이 높을수록 후보 토큰 수가 많아져 무작위성 증가
    max_completion_tokens=2048, # 텍스트 생성 상한
    top_p=1, # 누적 확률 범위 제한 X
    frequency_penalty=0, # 같은 표현 반복 불이익 점수
    presence_penalty=0, # 이미 등장한 주제를 다시 선택하는 경우 불이익 점수
)

# %% [markdown]
# ### 응답 객체에서 생성 텍스트 추출하기
#
# 응답의 `choices`는 생성 후보 목록이며, 이 예제는 첫 번째 후보의 `message.content`를 표시한다. 후보가 비어 있거나 API 호출이 실패하면 이 접근은 불가능하므로, 앞 셀의 정상 응답 여부를 먼저 확인해야 한다. 출력 텍스트는 모델의 생성물이지 검증된 사실이 아니므로 업무 규칙과 원문을 대조한다.

# %%
print(response.choices[0].message.content)
# Out:
# 안녕 아이유! 만나서 반가워요. 어떻게 도와줄까?

# %% [markdown]
# ## 프롬프팅의 기본구성
#
# https://www.deeplearning.ai/short-courses/chatgpt-prompt-engineering-for-developers/
#
# 1. Instruction 지시사항
# 2. Context 문맥
# 3. Input Data/Example 입력/예시
# 4. Output Indicator 출력지시

# %% [markdown]
# ## 기사 제목 교정
#
# - 기자들이 송고한 기사에서 제목을 추출하고, 표현 조정
# - 프랑스AFP 속보시스템에서 도입되어 사용

# %% [markdown]
# ### 기사 제목 교정 프롬프트 실행
#
# 이 셀은 역할과 교정 규칙을 `system_message`에, 실제 기사 제목을 `user_message`에 분리해 전달한다. 예시와 출력 형식은 모델이 두 제목을 정해진 구조로 반환하도록 돕는다. `print` 결과에서 비속어 완화, 핵심 정보 보존, 지정된 두 줄 형식이 모두 지켜졌는지 확인한다. API 응답은 실행 환경에 따라 달라지며 결과를 실제 관찰한 값처럼 미리 단정하지 않는다.

# %%
# 교정이 필요한 제목
title_before = '테이의 FM 개꿀 라디오 방송에 주목해주세요.'
title_before = '졸라 빡센 작업으로 끼니 거르기 일쑤인 노동자들의 애환'

# system 지시사항
# system 메시지에는 모든 제목에 공통으로 적용할 역할, 절차, 출력 형식, 예시를 넣는다.
system_message = """
기사들이 송고한 제목에서 맞춤법, 문법, 의미, 어조등에 있어서 교정작업을 수행해 주세요.

- 기사 제목이 명확하고 주제와 잘 맞도록 조정하세요.
- 독자의 관심을 끌 수 있도록 간결하면서도 임팩트 있는 표현을 사용하세요.
- 어조가 지나치게 감정적이거나 부정적인 경우 표현을 완화하거나, 중립적인 어조로 수정하세요.
- 비속어가 포함되어 있는 경우, 비속어를 반드시 제거하고, 의미를 적절히 유지하도록 제목을 교정하세요.

### Steps ###
1. 기사제목을 읽고 주요내용을 이해하세요.
2. 제목이 전달하고자하는 메세지를 명확하게 반영하는지 검토하세요.
3. 맞춤법, 문법, 의미 전달의 정확성등을 점검하고 적절히 수정하세요.
4. 제목이 자연스럽고, 독자에게 매력적으로 다가갈수 있는지 점검하고 매우 간결하게 정리하세요.


### Output Format ###
기사 원래 제목과 교정된 제목을 다음 형식으로 제공하세요.

- 원래 제목: [기사 원래 제목]
- 교정 제목: [교정 기사 제목]

### Examples ###
- 원래 제목: "어제 서울에서 큰 불이 나 수백명이 대피했다."
- 교정 제목: "서울 대형 화재, 수백명 대피"

- 원래 제목: "전기자동차 판매량 급감에 내연차회사들이 즐거워하는 중입니다."
- 교정 제목: "전기차 판매량 급감에 웃는 내연차회사들"

### Extra Instructions ###
- 제목이 너무 길면, 간결하게 줄이되, 핵심 메세지를 잃어버려서는 안됩니다.
- 지역명, 시간 등의 중요한 정보는 명확하게 유지하세요.
- 제목이 특정집단이나 대상에 대해 중립적이지 않을 경우, 그 표현을 완화하세요.

"""


# 이번 요청에서만 바뀌는 기사 제목을 user 메시지에 삽입
user_message = f"""
다음 기사 제목을 교정해주세요.

제목 : {title_before}
"""

response = client.chat.completions.create(
  model="gpt-4.1-mini",  # 제목 교정에 사용할 모델 ID이다.
  messages=[
    {
      "role": "system",  # 위에서 만든 공통 교정 규칙을 전달한다.
      "content": [
        {
          "type": "text",
          "text": system_message
        }
      ]
    },
    {
      "role": "user",  # 교정할 제목이 포함된 현재 요청을 전달한다.
      "content": [
        {
          "type": "text",
          "text": user_message
        }
      ]
    }
  ],
  response_format={
    "type": "text"  # 결과를 일반 문자열로 받는다.
  },
  temperature=1,  # 표현의 다양성을 조절한다.
  max_completion_tokens=2048,  # 교정 결과가 사용할 수 있는 생성 토큰 상한이다.
  top_p=1,  # 후보 토큰의 누적 확률 범위를 제한하지 않는다.
  frequency_penalty=0,  # 동일 표현 반복에 대한 추가 패널티를 사용하지 않는다.
  presence_penalty=0  # 새로운 주제 사용을 강제로 유도하지 않는다.
)

# 응답 결과 확인
print(response.choices[0].message.content)
# Out:
# - 원래 제목: 졸라 빡센 작업으로 끼니 거르기 일쑤인 노동자들의 애환
# - 교정 제목: 어려운 작업 환경 속 끼니를 거르는 노동자들의 현실

# %% [markdown]
# ### 반복 요청을 제목 교정 함수로 리팩터링하기
#
# `correct_news_title`은 제목, 모델 이름, `temperature`, `top_p`를 인자로 받아 같은 프롬프트 구조를 재사용한다. 함수의 반환값은 응답 텍스트이며, 호출한 쪽은 `output`에 저장해 출력하거나 후속 검증에 사용한다. 같은 제목을 여러 설정으로 비교할 때는 입력을 고정하고 생성 파라미터만 바꿔 형식 준수와 표현 차이를 비교한다.

# %%
def correct_news_title(title_before, model='gpt-4.1-mini', temperature=1, top_p=1):
    system_message = """
    기사들이 송고한 제목에서 맞춤법, 문법, 의미, 어조등에 있어서 교정작업을 수행해 주세요.

    - 기사 제목이 명확하고 주제와 잘 맞도록 조정하세요.
    - 독자의 관심을 끌 수 있도록 간결하면서도 임팩트 있는 표현을 사용하세요.
    - 어조가 지나치게 감정적이거나 부정적인 경우 표현을 완화하거나, 중립적인 어조로 수정하세요.
    - 비속어가 포함되어 있는 경우, 비속어를 반드시 제거하고, 의미를 적절히 유지하도록 제목을 교정하세요.

    ### Steps ###
    1. 기사제목을 읽고 주요내용을 이해하세요.
    2. 제목이 전달하고자하는 메세지를 명확하게 반영하는지 검토하세요.
    3. 맞춤법, 문법, 의미 전달의 정확성등을 점검하고 적절히 수정하세요.
    4. 제목이 자연스럽고, 독자에게 매력적으로 다가갈수 있는지 점검하고 매우 간결하게 정리하세요.


    ### Output Format ###
    기사 원래 제목과 교정된 제목을 다음 형식으로 제공하세요.

    - 원래 제목: [기사 원래 제목]
    - 교정 제목: [교정 기사 제목]

    ### Examples ###
    - 원래 제목: "어제 서울에서 큰 불이 나 수백명이 대피했다."
    - 교정 제목: "서울 대형 화재, 수백명 대피"

    - 원래 제목: "전기자동차 판매량 급감에 내연차회사들이 즐거워하는 중입니다."
    - 교정 제목: "전기차 판매량 급감에 웃는 내연차회사들"

    ### Extra Instructions ###
    - 제목이 너무 길면, 간결하게 줄이되, 핵심 메세지를 잃어버려서는 안됩니다.
    - 지역명, 시간 등의 중요한 정보는 명확하게 유지하세요.
    - 제목이 특정집단이나 대상에 대해 중립적이지 않을 경우, 그 표현을 완화하세요.

    """

    user_message = f"""
    다음 기사제목을 교정해주세요.

    제목: {title_before}
    """

    response = client.chat.completions.create(
        model=model,  # 호출자가 선택한 모델 ID이다.
        messages=[
            {
                "role": "system",
                "content": [
                    {
                    "type": "text",
                    "text": system_message
                    }
                ]
            },
            {
                "role": "user",  # 이번에 교정할 제목이다.
                "content": [
                    {
                    "type": "text",
                    "text": user_message
                    }
                ]
            }],
            response_format={
                "type": "text"
            },
        temperature=temperature,
        max_completion_tokens=2048,
        top_p=top_p,
        frequency_penalty=0,
        presence_penalty=0
    )
    # 호출부가 SDK 응답 구조를 몰라도 되도록 생성된 문자열만 반환한다.
    return response.choices[0].message.content

title_before = '주말 미친 폭우 예상, 모두들 무사하시길~'
output = correct_news_title(title_before)
print(output)
# Out:
# - 원래 제목: 주말 미친 폭우 예상, 모두들 무사하시길~
# - 교정 제목: 주말 많은 폭우 예상, 안전에 유의하세요

# %% [markdown]
# ## 연애코치 ReAct

# %% [markdown]
# ### ReAct 형식의 상담 프롬프트 함수 정의
#
# ReAct는 추론과 행동을 명시적으로 구분해 복잡한 작업을 단계적으로 수행하게 하는 프롬프팅 방식이다. 이 예제는 외부 도구 호출을 구현하지 않고 상황 분석·행동 계획·실행이라는 출력 구조를 요청한다. `dating_coach`는 사용자 고민 문자열을 받아 응답 텍스트를 돌려주며, 다음 두 셀이 서로 다른 입력에서 구조가 유지되는지 확인한다.

# %%
def dating_coach(prompt, model = 'gpt-4o-mini', temperature=1, top_p=1):
    # System_message : 지침 설정
    system_message = """
    << System Instruction >>
    어떤 상황에서든 최고의 논리적/감성적 관점을 적용하는 연애코치로써 사용자의 고민을 해결해 주세요.

    << Output Format >>
    1. 상황분석:

    2. 행동계획:

    3. 실행:
    """

    # User message : 사용자 입력 프롬포트를 일정 형식으로 가공한 형태
    user_message = f"""
    사용자 현재 상황:
    {prompt}
    """

    # Chat completion 요청
    response = client.chat.completions.create(
        model = model,
        messages=[
            {
                "role": "system",
                "content": [{"type": "text", "text": system_message}]
            },
            {
                "role" : "user",
                "content": [{"type": "text", "text": user_message}],
            }
        ],
        response_format={"type": "text" }, # 응답 타입 지정
        temperature=temperature,
        max_completion_tokens=2048,
        top_p=top_p,
        frequency_penalty=0,
        presence_penalty=0
    )

    # 첫번째 후보의 상담 결과 텍스트만 반환
    return response.choices[0].message.content

# %% [markdown]
# ### 첫 번째 상담 입력으로 출력 형식 확인
#
# 정의한 `dating_coach`에 기념일 선물이라는 한 문장 입력을 전달한다. 출력에서 상황 분석, 행동 계획, 실행 항목이 구분되는지와 안전하지 않거나 과도하게 단정적인 조언이 없는지를 확인한다. 실제 결과는 모델과 실행 시점에 따라 달라진다.

# %%
prompt = """
저 이번 주말에 여자친구와 100일에요. 기어겡 나느 선물을 하고 싶다. 뭐가 좋을까?
"""

print(dating_coach(prompt))
# Out:
# 1. 상황분석:
#    - 당신과 여자친구는 100일을 맞이하고 있습니다. 이는 두 사람의 관계에서 중요한 이정표로, 특별한 선물을 통해 그 의미를 더욱 부각시키고 싶어 하시는 것 같습니다.
#    - 여자친구의 취향과 현재 상황을 고려해야 합니다. 그녀가 좋아하는 것, 필요로 하는 것, 그리고 두 분의 관계에서 특별한 의미가 있는 아이템을 선택하는 것이 좋습니다.
#
# 2. 행동계획:
#    - **여자친구의 취향 파악**: 그녀가 어떤 것을 좋아하는지, 혹은 필요로 하는 것이 무엇인지 생각해 보세요. 예를 들어, 앤틱한 쥬얼리, 책, 패션 아이템, 뷰티 제품 등이 있을 수 있습니다.
#    - **특별한 경험 선물 고려**: 물질적인 선물 뿐만 아니라 둘만의 특별한 경험을 선물하는 것도 좋은 아이디어입니다. 근처의 멋진 레스토랑에서의 식사, 주말 여행, 혹은 그녀의 관심사에 맞춘 이벤트(콘서트, 전시회 등)를 계획해 볼 수 있습니다.
#    - **직접 만든 선물**: 손편지나 직접 만든 애착이 담긴 선물도 그녀에게 사랑을 전하는 좋은 방법입니다. 예를 들어, 함께한 추억을 담은 포토 북을 만들거나, 특별한 장식을 한 일기장을 선물할 수 있습니다.
#
# 3. 실행:
#    - 먼저, 여자친구에게 어떤 것을 좋아하는지 평소에 언급한 이야기를 떠올려 보세요. 그녀와 자주 이야기하며 알아본 취향을 바탕으로 선물을 결정합니다.
#    - 선물의 포장을 신경 써서 하여 특별한 느낌을 더해주면 좋습니다. 예를 들어, 그녀가 좋아하는 색의 포장지나 리본을 이용해 포장하면 더욱 기쁘게 받아들일 것입니다.
#    - 만약 특별한 경험을 선물하기로 했다면, 미리 예약을 해놓고, 서프라이즈 요소를 추가하여 더욱 특별하게 만들어 보세요. 예를 들어, 식사를 마친 후 선물을 주거나, 여행 중에 그녀를 위한 서프라이즈를 준비하는 것입니다.
#
# 이렇게 하면 멋진 100일을 기념할 수 있을 것입니다!

# %% [markdown]
# ### 두 번째 상담 입력으로 일반화 범위 확인
#
# 같은 함수를 다른 갈등 상황에 적용해 프롬프트 구조가 입력 변화에도 유지되는지 확인한다. 두 응답을 비교할 때는 문장 길이보다 상황에 맞는 행동 제안과 출력 형식 준수 여부를 기준으로 삼는다. 개인 관계 조언은 사실 판단이나 전문 상담을 대체하지 않는다는 한계도 함께 안내한다.

# %%
prompt = """
내가 친구들과 놀다가 여자친구 연락을 받지 못했어, 지금 단단히 삐져있는 상황이야. 어떻게 극복하면 좋을까?
"""

print(dating_coach(prompt))
# Out:
# 1. 상황분석:
#    지금 상황에서 당신은 여자친구의 연락이 없다는 사실에 불안감과 서운함을 느끼고 있습니다. 친구들과 즐겁게 시간을 보냈지만, 여자친구와의 소통 부족 때문에 기분이 상해있습니다. 이는 상대방과의 관계에서 중요한 소통의 결여로 인한 감정적인 반응으로 보입니다. 상처받은 기분을 정직하게 인식하고, 그것이 왜 생겼는지를 이해하는 것이 중요합니다.
#
# 2. 행동계획:
#    1. 감정 정리: 먼저 자신의 감정을 돌아보세요. 어떤 부분이 특히 서운했는지, 왜 연락이 없었는지에 대한 가능성을 고려해보세요.
#    2. 대화 준비: 감정을 정리한 후, 여자친구와 대화할 준비를 합니다. 상대방이 미처 연락하지 못한 이유가 있을 수 있으므로, 상황을 이해하려는 태도가 필요합니다.
#    3. 긍정적인 접근: 대화를 할 때는 비난보다는 “내가 너와의 소통을 좀 더 원했어”와 같은 표현으로 접근하여 감정을 전달하는 것이 효과적입니다.
#
# 3. 실행:
#    1. 여자친구에게 메시지를 보냅니다: “안녕! 오늘 너한테 연락이 없어서 조금 서운했어. 괜찮니?” 라고 시작해보세요.
#    2. 그녀의 반응을 기다리고, 대화를 이어가면서 상황을 이해하려 노력하세요. 만약 그녀가 바빴거나 놓쳤다면, 그에 대한 이해를 표현하세요.
#    3. 이후 감정이 소통되었다면, 이번 일을 통해 앞으로 더 나은 소통을 할 수 있는 방법에 대해 함께 이야기해보세요. 이렇게 문제를 극복하고 나면, 관계가 더 깊어질 수 있을 것입니다.

# %% [markdown]
# ## 냉털마스터 ReAct
# - 사용자는 냉장고에 남아있는 음식재료를 알려주면, LLM은 이를 바탕으로 어떤 음식을 만들지를 조언해준다.
# - Reasoning/Action을 끌어낼수 있는 적절한 프롬프팅을 작성한다.

# %% [markdown]
# ### 재료 기반 레시피 제안 함수 정의
#
# 이 함수는 재료 목록을 user 메시지에 넣고, 분석·계획·검증·최종 레시피 순서의 응답을 요청한다. 리스트인 `user_foods`는 f-string에서 문자열로 변환되어 프롬프트의 입력 맥락이 된다. 모델은 실제 식재료 상태나 알레르기를 알 수 없으므로, 생성한 레시피는 조리 전 안전성·보관 상태·알레르기 정보를 사용자가 다시 확인해야 한다.

# %%
def fridge_raid_master(user_foods, model='gpt-4o-mini', temperature=1, top_p=1):
    system_message = """
당신은 사용자 냉장고의 재료를 가지고 최고의 음식을 만들 수 있는 레시피를 추천하는 챗봇입니다.
현재 상황을 분석하고 실행계획을 세우며 추가 내용이 있을지 확인하는 꼼꼼함을 보여주세요.

## 지시사항

### 상황분석
1. **재료 확인**: 냉장고에 있는 재료 목록을 작성하고, 각 재료의 신선함과 사용 가능 시간을 파악합니다.
2. **요리 컨셉 설정**: 재료를 고려하여 요리의 주제를 정하고 잠재적인 요리 아이디어를 계획합니다.

### 실행계획
3. **목표 변경**: 사용 가능한 재료로 만들고자 하는 요리의 목표를 설정하고, 필요한 정보나 추가 자료를 조사합니다.
4. **전략 개발**: 단계별로 목표를 달성하기 위한 전반적인 요리 계획을 세웁니다.
    단, 사용자가 따라하기 쉽게 단계별 가이드를 작성해야 합니다.

### 검증 및 추가내용 확인
5. **레시피 검토**: 작성된 레시피를 검토하여 정보가 명확하고 완전한지 확인합니다.
6. **수정**: 필요 시 수정하여 최종 레시피를 완성합니다.

## 출력형식

1. 상황분석:
   - 재료 목록 및 상태
   - 요리 컨셉 및 아이디어

2. 실행계획:
   - 목표 및 세부 계획
   - 필요한 추가 자료 및 전략

3. 검증 및 추가내용 확인
   - 레시피의 정확성 검토
   - 수정 및 편집

4. 최종레시피
   - 사용자가 따라하기 쉽게 목록으로 작성
   - 필요한 준비물로 별도록 작성할것!

## Examples

- **Input**:
    사용자의 냉장고에는 현재 [무, 파, 두부]이/가 있습니다.
-   **Output**:
  1. 상황분석: 오늘은 냉장고에 있는 무, 파, 두부를 이용해 한식 스프를 만들어보겠습니다...
  2. 실행계획: 먼저 무와 파를 얇게 썰어 냄비에 넣고 물을 부어...
  3. 검증 및 추가내용 확인: 레시피를 확인한 결과, 무와 두부의 사용 방법에 대한 설명이 추가로 필요합니다...

## Notes

- 요리의 문화적 관련성과 감수성을 고려합니다.
- 레시피는 예상 독자의 요리 지식 수준에 맞게 조정됩니다.

    """
    # User message : 사용자 입력 프롬포트를 일정 형식으로 가공한 형태
    user_message = f"""
    사용자의 냉장고에는 현재 {user_foods}이/가 있습니다.
    """

    # Chat completion 요청
    response = client.chat.completions.create(
        model = model,
        messages=[
            {
                "role": "system",
                "content": [{"type": "text", "text": system_message}]
            },
            {
                "role" : "user",
                "content": [{"type": "text", "text": user_message}],
            }
        ],
        response_format={"type": "text" }, # 응답 타입 지정
        temperature=temperature,
        max_completion_tokens=2048,
        top_p=top_p,
        frequency_penalty=0,
        presence_penalty=0
    )

    return response.choices[0].message.content

# %% [markdown]
# ### 재료 목록을 Markdown 응답으로 표시하기
#
# `Markdown`과 `display`는 모델이 반환한 마크다운 형식의 레시피를 노트북에서 읽기 쉽게 렌더링한다. `user_foods`가 함수 입력이고 반환 문자열이 `Markdown`의 입력이 된다. 화면에서는 네 개의 출력 구역이 실제로 구분되는지와 재료 목록이 모두 반영되었는지 확인한다.

# %%
from IPython.display import display, Markdown

# %%
user_foods = ['소고기 부채살', '양파', '새송이 버섯', '명란젓', '배추김치', '된장']
print(fridge_raid_master(user_foods))
display(Markdown(fridge_raid_master(user_foods)))
# Out:
# 1. **상황분석**:
#    - **재료 목록 및 상태**:
#      - 소고기 부채살: 신선함이 좋음
#      - 양파: 신선함 좋음
#      - 새송이 버섯: 신선함 좋음
#      - 명란젓: 가공품으로 장기간 보관 가능
#      - 배추김치: 발효된 상태로 보관 가능
#      - 된장: 발효된 상태로 장기간 보관 가능
#
#    - **요리 컨셉 및 아이디어**:
#      - 상황에 맞게 한국식 메인 요리로 **소고기 볶음**과 **된장찌개**를 기반으로 한 요리를 계획합니다. 소고기 부채살과 양파, 새송이 버섯을 활용하여 맛있고 영양가 있는 볶음을 만들고, 배추김치와 된장을 활용하여 간단한 된장찌개로 서브할 수 있습니다. 명란젓은 반찬으로 사용합니다.
#
# 2. **실행계획**:
#    - **목표 및 세부 계획**:
#      - 주 요리: 소고기 볶음
#      - 서브 요리: 된장찌개
#      - 반찬: 명란젓
#      1. 소고기, 양파, 새송이 버섯을 재료 준비하여 볶음 요리를 만든다.
#      2. 별도로 된장찌개를 준비하여 배추김치와 잘 어울리게 한다.
#
#    - **필요한 추가 자료 및 전략**:
#      - 소고기 볶음의 양념 (간장, 마늘, 후춧가루) 정보를 정리한다.
#      - 된장찌개 만들 때 필요한 다른 재료 (청양고추, 두부 등) 여부 확인.
#
# 3. **검증 및 추가내용 확인**:
#    - 레시피 초안 검토: 소고기 볶음과 된장찌개의 조리 방법 및 비율을 명확히 제시한다. 양념과 조리 과정에 대한 상세한 설명이 필요하다.
#
# 4. **최종레시피**:
#    - **소고기 볶음**
#      - 준비물:
#        - 소고기 부채살 200g
#        - 양파 1개
#        - 새송이 버섯 1~2개
#        - 간장 2큰술
#        - 마늘 1쪽 (다진 것)
#        - 후춧가루 적당량
#        - 식용유 1큰술
#
#    - **된장찌개**
#      - 준비물:
#        - 물 3컵
#        - 된장 2큰술
#        - 배추김치 1컵 (잘게 썬 것)
#        - 두부 1/2모 (선택사항)
#        - 청양고추 1~2개 (선택사항)
#
#    - **조리법**:
#      1. 소고기 부채살은 얇게 썰고, 양파는 채 썰고, 새송이버섯은 슬라이스합니다.
#      2. 팬에 식용유를 두르고, 다진 마늘을 넣고 볶다가 향이 나면 소고기를 넣고 볶습니다.
#      3. 고기가 익으면 양파와 새송이가 들어가고, 간장과 후춧가루로 간을 맞춥니다. 모두 잘 볶아지면 불을 끄고 접시에 담습니다.
#
#    - **된장찌개 조리법**:
#      1. 물을 끓인 후 된장을 넣고 잘 풀어줍니다.
#      2. 배추김치와 두부를 넣고 끓입니다. 필요한 경우 청양고추를 넣어 매운맛을 추가합니다.
#      3. 모든 재료가 익을 때까지 끓인 후, 불을 끄고 그릇에 담습니다.
#
#    - **서빙**:
#      - 소고기 볶음과 된장찌개를 함께 서빙하고, 명란젓을 밑반찬으로 곁들여서 즐깁니다.
#
# 이 레시피를 통해 맛있고 간단한 한끼를 준비할 수 있습니다. 추가로 궁금한 점이나 필요한 내용이 있으면 말씀해 주세요!
# 1. **상황분석**:
#    - **재료 목록 및 상태**:
#      - 소고기 부채살: 신선하며 요리에 적합합니다.
#      - 양파: 신선하고 사용 가능.
#      - 새송이 버섯: 신선하여 요리에 잘 어울립니다.
#      - 명란젓: 신선하며 특별한 맛을 더해줄 것입니다.
#      - 배추김치: 신선하고 잘 조리하면 맛을 더해줍니다.
#      - 된장: 안정성이 좋으며 사용 가능.
#
#    - **요리 컨셉 및 아이디어**:
#      오늘은 ‘소고기 부채살’을 주재료로 하여, ‘된장찌개’와 ‘명란젓 볶음’을 곁들이는 간단한 한식을 만들어 보겠습니다. 배추김치는 반찬으로 곁들여 맛을 극대화할 수 있습니다.
#
# 2. **실행계획**:
#    - **목표**:
#      소고기 부채살과 다른 재료를 활용하여 맛있는 한식 찌개와 볶음을 만들기로 합니다.
#
#    - **세부 계획**:
#      1. 소고기 부채살을 큐브 모양으로 썰기.
#      2. 양파를 얇게 썰고, 새송이 버섯을 슬라이스합니다.
#      3. 준비한 재료를 가지고 된장찌개를 만들기.
#      4. 명란젓을 볶아 곁들일 반찬 준비.
#      5. 배추김치를 별도 접시에 담아 제공합니다.
#
#    - **필요한 추가 자료 및 전략**:
#      - 각 단계별 조리 시간과 조리법에 대한 정보가 필요합니다. 특히 된장찌개의 요리 방법 및 명란젓을 볶는 요령에 대한 세부 지침을 포함하겠습니다.
#
# 3. **검증 및 추가내용 확인**:
#    - 작성된 레시피를 확인한 결과, 각 재료의 준비 방법과 조리시간에 대한 설명을 추가해야 할 필요가 있습니다. 또한 된장찌개와 명란젓 볶음의 조리 과정이 상세히 설명되어야 합니다.
#
# 4. **최종레시피**:
#
# ### 필요 준비물
# - 소고기 부채살 200g
# - 양파 1개
# - 새송이 버섯 2개
# - 명란젓 100g
# - 배추김치 1컵
# - 된장 2큰술
# - 물 4컵 (또는 원하는 농도에 맞춰 조절)
# - 식용유
#
# ### 요리 순서
# 1. **재료 준비**:
#    - 소고기 부채살을 큐브 모양으로 썰고, 양파는 채 썰고, 새송이 버섯은 슬라이스합니다.
#
# 2. **된장찌개 만들기**:
#    1. 큰 냄비에 물을 넣고 끓입니다.
#    2. 끓는 물에 된장을 넣고 잘 풀어줍니다.
#    3. 썬 양파와 새송이 버섯을 넣고 5분 정도 끓입니다.
#    4. 소고기 부채살을 넣고 한소끔 끓입니다.
#    5. 마지막으로 국물이 끓어오르면 불을 끄고 맛을 확인 후 필요하면 간을 추가합니다.
#
# 3. **명란젓 볶음 만들기**:
#    1. 팬에 식용유를 두르고 중불로 예열합니다.
#    2. 명란젓을 넣고 약 1~2분 정도 볶아줍니다.
#    3. 기호에 따라 먹기 좋은 크기로 잘라서 제공하면 됩니다.
#
# 4. **서빙**:
#    - 된장찌개를 그릇에 담고, 볶은 명란젓을 같이 서빙합니다.
#    - 배추김치를 따로 제공하여 한상차림을 완성합니다.
#
# 이제 맛있게 드시면 됩니다! 필요에 따라 다른 곁들이 재료를 추가할 수 있습니다.

# %% [markdown]
# ## 면접질문 생성 JSON 출력

# %% [markdown]
# ### JSON 형식 면접 질문 생성 함수 정의
#
# 이 함수는 채용공고 문자열을 받아 hard skill과 soft skill 질문·답변을 담은 JSON 문자열을 요청한다. `response_format={"type": "json_object"}`는 JSON 객체 형식의 응답을 요구하지만, 실제 파싱 전에는 필수 키와 값의 타입을 검증해야 한다. 함수는 아직 API를 호출하지 않으며 다음 셀의 채용공고가 입력으로 전달될 때 호출된다.

# %%
def job_interview(job_posting, model = 'gpt-4o-mini', temperature=1, top_p=1):
    system_message = """
당신은 머신러닝/딥러닝/LLM/AI서비스개발의 전문가로써, 해당분야의 으뜸가는 면접관입니다.
매번 그룹사의 인재를 발굴하기 위해 면접질문/모범답안을 작성하고 있습니다.

<<지시사항>>
- 사용자가 제출한 채용공고의 내용을 바탕으로 예상면접질문과 답변을 작성해주세요.
- 하드스킬과 소프트스킬 두개의 섹션으로 나누어 작성해주세요.
- 각 스킬별로 질문/답변을 3개씩 만들어주세요.

<<출력형식>>
출력은 json형식으로만 반환되어야 합니다.

{{
    "hard_skill": [
        {{
            "question": "",
            "answer": "",
        }}
    ],
    "soft_skill": [
        {{
            "question": "",
            "answer": "",
        }}
    ]
}}
"""

    user_message = f"""
    채용공고 : {job_posting}
"""

    # Chat completion 요청
    response = client.chat.completions.create(
        model = model,
        messages=[
            {
                "role": "system",
                "content": [{"type": "text", "text": system_message}]
            },
            {
                "role" : "user",
                "content": [{"type": "text", "text": user_message}],
            }
        ],
        response_format={"type": "text" }, # 응답 타입 지정
        temperature=temperature,
        max_completion_tokens=2048,
        top_p=top_p,
        frequency_penalty=0,
        presence_penalty=0
    )

    return response.choices[0].message.content

# %% [markdown]
# ### 채용공고를 입력으로 전달하고 원본 응답 확인
#
# 긴 `job_posting` 문자열은 모델이 근거로 삼을 입력 데이터이며, `output`은 함수가 반환한 JSON 문자열이다. 먼저 `type(output)`이 `str`인지와 내용이 JSON 객체처럼 보이는지 확인한 뒤 다음 셀에서 파싱한다. 실제 API 호출은 비용과 네트워크가 발생하므로 수업 환경의 키와 사용 한도를 확인한 뒤 실행한다.

# %%
job_posting = """
| 모집부문                      | 담당업무                                                                                                                                                                                                                                                                                               | 자격요건 및 필수사항                                                                                                                                                                                                                                                                                                                                                                 |
| ------------------------- | -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
| **AI 인프라 구축 (ML/DEVOps)** | 1. AI 모델의 배포를 위한 인프라 구축 및 운영2. 알고리즘 개발자에 대한 기술 지원3. 머신러닝 인프라의 설계 및 개발, 운영4. 모니터링, 로깅 시스템의 개발 및 구현5. 머신러닝 시스템의 학습, 배포, 테스트 환경 구축, 운영 및 자동화6. 오픈소스 기반의 플랫폼 통합 및 내재화 구축(MLflow, LakeFS, CVAT, BentoML 등)7. 보안, 인증, 권한 관리 등 운영 정책 및 관리자 기능 구축8. 시스템과 프로세스에 대한 문서 작업 |
**학력**- 대졸이상(4년제)**경력**- 신입**필수사항**- Python 프로그래밍 능력- 컨테이너 오케스트레이션 툴 활용 능력(Docker, Kubernetes 등)- Jenkins, ArgoCD, Gitlab 등 구축 및 운영 경험**우대사항**- DevOps 환경 구축 혹은 DevOps 환경에서 개발 및 배포 경험 보유자- MLflow, Kubeflow, ML 모델 서빙 플랫폼 등과 관련된 실무 경험 보유자- Kubernetes, Docker, GitOps, CI/CD, Vault, MinIO 등 클라우드 네이티브 인프라 경험 보유자 |
"""

print(job_interview(job_posting))
# Out:
# {
#     "hard_skill": [
#         {
#             "question": "Python 프로그래밍에서 객체 지향 프로그래밍의 원칙에 대해 설명해 주세요.",
#             "answer": "객체 지향 프로그래밍(OOP)의 4대 원칙은 캡슐화, 상속, 다형성, 추상화입니다. 캡슐화는 데이터와 메소드를 하나의 단위로 묶어 정보 은닉을 통해 외부 접근을 제한하는 것이고, 상속은 기존 클래스를 기반으로 새로운 클래스를 만들어서 코드 재사용성을 높이는 것입니다. 다형성은 동일한 메소드가 다양한 형태로 작동하게 만드는 것으로, 추상화는 복잡한 시스템을 단순화하여 중요한 요소만 남기는 과정을 의미합니다."
#         },
#         {
#             "question": "컨테이너 오케스트레이션 도구인 Kubernetes의 주요 컴포넌트에 대해 설명해 주세요.",
#             "answer": "Kubernetes의 주요 컴포넌트에는 클러스터, 노드, 파드, 서비스, 레플리카셋, 스테이트풀셋, 데몬셋 등이 있습니다. 클러스터는 여러 노드의 집합체이며, 노드는 컨테이너화된 애플리케이션을 실행하는 머신입니다. 파드는 하나 이상의 컨테이너 그룹을 의미하며, 서비스는 파드를 외부와 연결시키는 역할을 합니다. 레플리카셋은 파드의 복제본을 관리하고, 스테이트풀셋은 상태를 유지해야 하는 애플리케이션을 관리합니다."
#         },
#         {
#             "question": "CI/CD 파이프라인 구축 경험에 대해 이야기해 주세요.",
#             "answer": "저는 GitLab과 Jenkins를 사용하여 CI/CD 파이프라인을 구축한 경험이 있습니다. 코드를 GitLab에 푸시하면 Jenkins가 이를 감지하고 자동으로 빌드와 테스트 과정을 실행하도록 설정했습니다. 이 과정에서 Docker를 통해 컨테이너를 생성하였고, 모든 테스트가 통과하면 자동으로 Kubernetes 클러스터에 배포하도록 구성했습니다. 이를 통해 개발 주기를 단축하고 안정성을 높일 수 있었습니다."
#         }
#     ],
#     "soft_skill": [
#         {
#             "question": "팀원들과의 효과적인 커뮤니케이션을 위해 어떤 노력을 하고 있나요?",
#             "answer": "저는 주기적으로 스탠드업 미팅을 주최하여 팀원들과의 소통을 강화하고, 진행 중인 작업에 대한 업데이트를 공유합니다. 또한, 프로젝트 관리 도구를 활용하여 각자의 작업 상태를 시각적으로 공유함으로써 모든 팀원이 프로젝트의 전반적인 진행 상황을 쉽게 알 수 있도록 하고 있습니다. 문제가 발생할 경우 적극적으로 피드백을 공유하고 수용함으로써 서로의 의견을 존중합니다."
#         },
#         {
#             "question": "새로운 기술을 배우는 데 있어 어떤 접근 방식을 취하나요?",
#             "answer": "저는 새로운 기술을 배우기 위해 온라인 강의와 튜토리얼을 활용하고, 실제 프로젝트에 적용해 보는 방법을 선호합니다. 이론적으로 배운 내용을 실제로 구현해보는 과정에서 주어진 문제를 해결하며 깊이 있는 이해를 할 수 있습니다. 또한, 유사한 기술을 사용하는 개발자들과 함께 학습하고 협업하여 서로의 경험을 공유하는 것이 매우 도움이 된다고 생각합니다."
#         },
#         {
#             "question": "프레셔 상황에서 어떻게 문제를 처리하나요?",
#             "answer": "프레셔 상황에서 작업할 때는 우선 침착을 유지하고 문제를 분석하여 우선 순위를 정합니다. 체계적으로 문제를 접근하기 위해 가능한 해결책을 나열하고, 팀원과의 협업을 통해 다양한 아이디어를 모색합니다. 이런 과정에서 필요한 경우 도움을 요청하고, 문제 해결을 위한 책임을 분담함으로써 더 나은 결과를 도출할 수 있도록 노력합니다."
#         }
#     ]
# }

# %% [markdown]
# ### 지시문과 입력 데이터를 분리한 JSON 프롬프트
#
# 이 셀은 시스템 역할 설명과 사용자 쪽의 지시·채용공고를 분리해 같은 JSON 생성 함수를 다시 정의한다. 프롬프트 구성 요소를 분리하면 역할 규칙은 재사용하고 채용공고만 바꿀 수 있다. 두 함수 정의는 같은 이름을 사용하므로 이 셀을 실행하면 앞 셀의 정의를 덮어쓴다는 점을 확인한다.

# %%
def job_interview(job_posting, model='gpt-4o-mini', temperature=1, top_p=1):
    # system 메시지에는 여러 요청에서 유지할 면접관 역할만 둔다.
    system_message = """
당신은 머신러닝/딥러닝/LLM/AI서비스개발의 전문가로써, 해당분야의 으뜸가는 면접관입니다.
매번 그룹사의 인재를 발굴하기 위해 면접질문/모범답안을 작성하고 있습니다.
"""

    # 작업 지시, JSON 예시, 실제 채용공고를 한 user 메시지의 경계 표식으로 구분한다.
    # {{와 }}는 f-string이 JSON 중괄호를 변수 자리로 해석하지 않게 한다.
    user_message = f"""

<<지시사항>>
- 사용자가 제출한 채용공고의 내용을 바탕으로 예상면접질문과 답변을 작성해주세요.
- 하드스킬과 소프트스킬 두개의 섹션으로 나누어 작성해주세요.
- 각 스킬별로 질문/답변을 3개씩 만들어주세요.

<<출력형식>>
출력은 json형식으로만 반환되어야 합니다.

{{
    "hard_skill": [
        {{
            "question": "",
            "answer": "",
        }}
    ],
    "soft_skill": [
        {{
            "question": "",
            "answer": "",
        }}
    ]
}}

<< 채용공고 >>
{job_posting}
"""
        # 역할 메시지와 작업 메시지를 결합하고 JSON mode로 응답을 요청한다.
    response = client.chat.completions.create(
        model=model,  # 함수 호출 시 선택한 모델 ID이다.
        messages=[
            {
                "role": "system",
                "content": [
                    {
                    "type": "text",
                    "text": system_message
                    }
                ]
            },
            {
                "role": "user",
                "content": [
                    {
                    "type": "text",
                    "text": user_message
                    }
                ]
            }],
            # JSON 문법은 보장하지만 hard_skill 같은 필드 존재 여부는 코드에서 별도로 검사해야 한다.
            response_format={
                "type": "json_object"
            },
        temperature=temperature,
        max_completion_tokens=2048,
        top_p=top_p,
        frequency_penalty=0,
        presence_penalty=0
    )

    return response.choices[0].message.content

# %% [markdown]
# ### JSON 문자열을 Python 자료구조로 변환하기
#
# `json.loads`는 JSON 문자열 `output`을 Python 딕셔너리로 변환한다. 변환 뒤 `hard_skill`과 `soft_skill` 키로 질문·답변 목록을 꺼내 후속 화면 표시, 파일 저장, 평가에 사용할 수 있다. JSON 문법이 깨지거나 필수 키가 없으면 오류가 나므로, API 응답 형식과 키 존재를 검증하는 것이 실무에서 중요하다.

# %%
import json # json -> dict 변환


output = job_interview(job_posting)
data = json.loads(output)

hard_skill_qa = data['hard_skill']
soft_skill_qa = data['soft_skill']

print(hard_skill_qa)
print("-" * 100)
print(soft_skill_qa)
# Out:
# [{'question': 'Python을 사용하여 머신러닝 모델을 배포하는 과정을 설명해 주세요.', 'answer': 'Python을 사용하여 머신러닝 모델을 배포하는 과정에는 모델 훈련, 모델 저장, REST API 서버 구축, 그리고 클라우드 또는 온프레미스 환경에 배포하는 단계가 포함됩니다. 먼저, 모델을 훈련한 후에는 Pickle이나 Joblib과 같은 방법으로 모델을 파일로 저장합니다. 그런 다음 Flask나 FastAPI를 이용하여 REST API 서버를 구현한 뒤, Docker를 사용하여 컨테이너로 패키징하고, Kubernetes 클러스터에 배포하여 확장성과 유연성을 확보합니다.'}, {'question': 'Docker와 Kubernetes를 활용한 CI/CD 파이프라인 구축 경험에 대해 말씀해 주세요.', 'answer': 'Docker와 Kubernetes를 활용한 CI/CD 파이프라인 구축에서, 우선 다양한 애플리케이션을 Docker 컨테이너로 패키징하고 GitLab CI를 설정하여 코드 변경 시 자동 빌드를 수행합니다. 이후 테스트가 성공하면 Kubernetes 클러스터에 배포하며, 이 과정에서 ArgoCD를 통한 배포 관리를 적용하여 GitOps 방식을 채택합니다. 이로 인해 배포 프로세스의 자동화와 일관성을 보장할 수 있었습니다.'}, {'question': 'MLflow를 사용한 모델 관리 경험에 대해 설명해 주세요.', 'answer': 'MLflow를 사용하여 모델 관리를 하는 과정은 모델 실험 추적, 패키징, 배포를 포함합니다. 첫째, mlflow.log_param()과 mlflow.log_metric()을 사용하여 모델 훈련 시 하이퍼파라미터와 성능 지표를 추적합니다. 이후 모델을 MLflow 모델 레지stry에 등록하여 버전 관리를 수행하고, 사용자 요청에 따라 REST API로 모델을 배포하여 실시간 예측을 제공합니다. 이 모든 과정에서 MLflow의 UI를 활용하여 모델의 가시성과 관리를 용이하게 했습니다.'}]
# ----------------------------------------------------------------------------------------------------
# [{'question': '팀원과의 협업에서 가장 중요하다고 생각하는 요소는 무엇인가요?', 'answer': '팀원과의 협업에서 가장 중요하다고 생각하는 요소는 소통입니다. 의견 차이가 발생할 때 명확하게 의사소통하고, 이해관계를 조율하는 것이 팀의 동기화와 생산성을 높이는 데 큰 도움이 됩니다. 정기적인 미팅 개최와 피드백을 통해 서로의 의견을 존중하고, 함께 문제를 해결하는 자세가 중요합니다.'}, {'question': '문제를 해결하기 위해 어떤 접근 방식을 취하시나요?', 'answer': '문제를 해결하기 위해 우선 문제의 본질을 파악하고, 여러 해결책을 탐색하는 데 중점을 둡니다. 문제를 분해하고 데이터를 분석하여 원인을 규명한 뒤, 다양한 대안 중 최적의 접근 방식을 선택하여 실행합니다. 실행 후 성과를 모니터링하고 필요시 조정하는 과정도 매우 중요합니다.'}, {'question': '일을 진행하면서 만나게 된 어려움을 어떻게 극복하나요?', 'answer': '어려움을 극복하는 데 있어 저는 먼저 침착하게 문제를 분석하고, 상황을 다른 관점에서 바라보려고 노력합니다. 필요한 경우 동료들의 조언을 구하고, 협업을 통해 다양한 관점과 아이디어를 수집하며 해결책을 찾습니다. 또한, 실패를 통해 배우고 지속적으로 개선해 나가는 태도를 가지고 있습니다.'}]
